# %%
import rpyc
c = rpyc.connect("localhost", 50001, config ={"allow_all_attrs": True})

# %%
from PIL import Image

im = Image.open('teste.png')

# %%
img, person, tmp = c.root.exposed_detect(im=im.copy())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-27e6a3ff5f2c> in <module>
# ----> 1 img, person, tmp = c.root.exposed_detect(im=im.copy())
#
# ~/.conda/envs/svision/lib/python3.6/site-packages/rpyc/core/netref.py in __call__(_self, *args, **kwargs)
#     245         def __call__(_self, *args, **kwargs):
#     246             kwargs = tuple(kwargs.items())
# --> 247             return syncreq(_self, consts.HANDLE_CALL, args, kwargs)
#     248         __call__.__doc__ = doc
#     249         return __call__
#
# ~/.conda/envs/svision/lib/python3.6/site-packages/rpyc/core/netref.py in syncreq(proxy, handler, *args)
#      74     """
#      75     conn = object.__getattribute__(proxy, "____conn__")
# ---> 76     return conn.sync_request(handler, proxy, *args)
#      77
#      78
#
# ...

# %% [markdown]
# ## Testes diretos

# %%
import sys
import os
import time
sys.path.append('./YOLOv3/yolov3/')
sys.path.append('./YOLOv3/yolov3/model_data/')

from yolo import YOLO
from image_detect import yolo_detect

# %%
from PIL import Image
im = Image.open('imgs/teste.jpg').convert('RGB')

yolo = YOLO()
inicio = time.time()
draw, qtd_person = yolo_detect(yolo, im)
fim = time.time()
yolo.close_session()
# Out:
# WARNING:tensorflow:From ./YOLOv3/yolov3/yolo.py:44: The name tf.keras.backend.get_session is deprecated. Please use tf.compat.v1.keras.backend.get_session instead.
#
# ./YOLOv3/yolov3/model_data/yolo.h5 model, anchors, and classes loaded.
# WARNING:tensorflow:From /home/jupyter-davidm/.conda/envs/svision/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
from matplotlib import pyplot as plt 
# %matplotlib inline
plt.imshow(draw)

# %%
import pyscreenshot as ImageGrab

# %%
im = ImageGrab.grab(bbox=(10, 10, 510, 510)) # X1,Y1,X2,Y2
im.show()
